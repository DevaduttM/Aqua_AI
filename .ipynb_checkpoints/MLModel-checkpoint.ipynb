# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("Water_Quality_Testing.csv")

# %%
df
# Out:
#        pH  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 0    7.25              23.1              4.5                      7.8
# 1    7.11              22.3              5.1                      6.2
# 2    7.03              21.5              3.9                      8.3
# 3    7.38              22.9              3.2                      9.5
# 4    7.45              20.7              3.8                      8.1
# ..    ...               ...              ...                      ...
# 495  7.01              20.8              4.6                      7.1
# 496  7.31              22.5              3.8                      9.4
# 497  7.02              21.2              4.7                      7.5
# 498  7.25              23.0              3.9                      8.7
# 499  7.12              20.9              4.4                      8.2
#
#      Conductivity (µS/cm)    Hardness  Safe
# 0                     342  204.890456     0
# ...

# %%
y = df["Safe"]
X = df.drop(columns = 'Safe')
X
# Out:
#        pH  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 0    7.25              23.1              4.5                      7.8
# 1    7.11              22.3              5.1                      6.2
# 2    7.03              21.5              3.9                      8.3
# 3    7.38              22.9              3.2                      9.5
# 4    7.45              20.7              3.8                      8.1
# ..    ...               ...              ...                      ...
# 495  7.01              20.8              4.6                      7.1
# 496  7.31              22.5              3.8                      9.4
# 497  7.02              21.2              4.7                      7.5
# 498  7.25              23.0              3.9                      8.7
# 499  7.12              20.9              4.4                      8.2
#
#      Conductivity (µS/cm)    Hardness
# 0                     342  204.890456
# 1                     335  129.422921
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train);
X_train_scaled
# Out:
# array([[-0.00680176,  1.07455776, -1.46936279,  0.88205157,  0.75302693,
#          1.21507981],
#        [-0.84156305, -1.59515096, -1.7235778 , -0.82357301, -1.15670096,
#          0.17373527],
#        [ 0.271452  , -0.70524805,  0.31014232, -0.70174268, -0.62197715,
#         -1.06055339],
#        ...,
#        [-1.02706556,  0.74084417,  1.32700238, -1.43272464, -0.69836627,
#          0.98440687],
#        [-1.21256807,  0.40713058, -0.45250273, -0.09259105, -1.92059212,
#         -0.60176791],
#        [ 0.64245702,  1.40827135,  1.07278736,  1.61303353,  1.1349725 ,
#          0.91924605]])

# %%
X_test_scaled = scaler.transform(X_test);

# %%
log_reg = LogisticRegression(random_state = 0, C = 10).fit(X_train_scaled, y_train)

# %%
input = scaler.transform([[4.02, 20.7, 4.8, 7.5, 320, 227.23]])

# %%
log_reg.predict(input)
# Out:
# array([1], dtype=int64)

# %%
log_reg.score(X_test_scaled, y_test)
# Out:
# 0.94
